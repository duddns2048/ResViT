# %%
import nibabel as nib

# Load the NIfTI file
nii_image = nib.load('../DATASET/BRATS2024/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/fold_0/test/BraTS-GLI-00003-000/BraTS-GLI-00003-000-t1c.nii.gz')

# Get the affine matrix
affine_matrix = nii_image.affine

# Print the affine matrix
print("Affine matrix:\n", affine_matrix)
# Out:
# Affine matrix:
#  [[ -1.  -0.  -0.   0.]
#  [ -0.  -1.  -0. 239.]
#  [  0.   0.   1.   0.]
#  [  0.   0.   0.   1.]]

# %%
import numpy as np
volume = np.zeros((256, 256, 100))
nii_image = nib.Nifti1Image(volume, affine=affine_matrix)
nib.save(nii_image, f'./results/testtest.nii.gz')

# %%
import os
dir_path = '/home/kimyw/github/DATASET/BRATS2024/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/fold_0/test'
for base, _, files in sorted(os.walk(dir_path)):
    for file in files:
        if file.endswith("t2f.nii.gz"):
            print(base)
            print(file)
    print('----------')
# Out:
# ----------
# /home/kimyw/github/DATASET/BRATS2024/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/fold_0/test/BraTS-GLI-00002-000
# BraTS-GLI-00002-000-t2f.nii.gz
# ----------
# /home/kimyw/github/DATASET/BRATS2024/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/fold_0/test/BraTS-GLI-00003-000
# BraTS-GLI-00003-000-t2f.nii.gz
# ----------
# /home/kimyw/github/DATASET/BRATS2024/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/fold_0/test/BraTS-GLI-00008-000
# BraTS-GLI-00008-000-t2f.nii.gz
# ----------
# /home/kimyw/github/DATASET/BRATS2024/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/fold_0/test/BraTS-GLI-00008-001
# BraTS-GLI-00008-001-t2f.nii.gz
# ----------
# /home/kimyw/github/DATASET/BRATS2024/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/fold_0/test/BraTS-GLI-00009-001
# BraTS-GLI-00009-001-t2f.nii.gz
# ----------
# /home/kimyw/github/DATASET/BRATS2024/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/fold_0/test/BraTS-GLI-00011-000
# BraTS-GLI-00011-000-t2f.nii.gz
# ...

# %%
import numpy as np
numpy_list = []
for i in range(20):
    numpy_list.append(np.zeros((100,100,1)))


result = np.concatenate(numpy_list, axis=2)
result.shape
# Out:
# (100, 100, 20)

# %%
import os

# 파일이 있는 디렉터리 경로 지정
directory = './results/fold0/'

# 디렉터리 내 모든 파일 및 디렉터리 목록 가져오기
for filename in os.listdir(directory):
    # 파일 경로 생성
    file_path = os.path.join(directory, filename)
    
    # 디렉터리인 경우 스킵
    if os.path.isdir(file_path):
        continue
    
    # 새로운 파일 이름 생성
    new_filename = 'BraTS-GLI-' + filename
    
    # 새로운 파일 경로 생성
    new_file_path = os.path.join(directory, new_filename)
    
    # 파일 이름 변경
    os.rename(file_path, new_file_path)

print("모든 파일의 이름 변경 완료")
# Out:
# 모든 파일의 이름 변경 완료

# %%
import random 

avail_fn = [1,1,1,1]
random_number = random.randint(0, 3)
avail_fn[random_number] = 0
avail_fn
# Out:
# [1, 0, 1, 1]

# %%
a = [1,1,0,1, 0]

a.index(0)
# Out:
# 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# x 값의 범위를 설정합니다. log(x)는 x > 0인 경우에만 정의됩니다.
x = np.linspace(0, 1, 400)

# -log(1-x)를 계산합니다.
y = -np.log(x)

# 그래프를 그립니다.
plt.plot(x, y, label='-log(x)')

# 그래프의 제목과 축 레이블을 추가합니다.
plt.title('-log(x) Graph')
plt.xlabel('x')
plt.ylabel('-log(x)')

# 범례를 추가합니다.
plt.legend()

# y=0 축을 더 굵게 그립니다.
plt.axhline(0, color='black', linewidth=2)
plt.axvline(0, color='black', linewidth=1)
plt.axvline(1, color='black', linewidth=1)

# x축 눈금을 0.2 단위로 설정합니다.
plt.xticks(np.arange(0, 1.1, step=0.2))

# 격자 선의 두께를 조정합니다.
plt.grid(True, linewidth=0.5)

# 그래프를 표시합니다.
plt.show()
# Out:
# /tmp/ipykernel_734825/2174051783.py:8: RuntimeWarning: divide by zero encountered in log
#   y = -np.log(x)

# %%
import torch.nn as nn
import torch

criterion = nn.BCELoss()

real = torch.tensor([1.])
fake = torch.tensor([0.])

pred = torch.tensor([0.5])

real_loss = criterion(pred, real)
fake_loss = criterion(pred, fake)

# %%
import numpy as  np

np.log(0.01)
# Out:
# -4.605170185988091

# %%
2.718**(4.605170185988091)
# Out:
# 99.95226302634202

# %%
real_loss
# Out:
# tensor(0.0101)

# %%
fake_loss
# Out:
# tensor(4.6052)

# %%
import matplotlib.pyplot as plt
import re

# Sample data from the txt file
data = """
epoch: 1 | iter: [79/77]G_GAN: 0.4461769122321894 G_L1: 5.181984946985913 D_real: 0.4408806380192945 D_fake: 0.32956148242684685 
epoch: 2 | iter: [157/77]G_GAN: 0.4053535712942196 G_L1: 2.739564172781197 D_real: 0.31951227760428835 D_fake: 0.2831931800646767 
epoch: 3 | iter: [235/77]G_GAN: 0.6022357671124161 G_L1: 2.8555214389873917 D_real: 0.3036777696032433 D_fake: 0.2267621560524137 
epoch: 4 | iter: [313/77]G_GAN: 0.598328884050345 G_L1: 2.6816051082246624 D_real: 0.30878646173484764 D_fake: 0.22805360373534828 
epoch: 5 | iter: [391/77]G_GAN: 0.3536695698454122 G_L1: 2.624341414992217 D_real: 0.27468775184291183 D_fake: 0.30170105263799313 
epoch: 6 | iter: [469/77]G_GAN: 0.42327244722159807 G_L1: 2.5987603694769987 D_real: 0.22676034309681814 D_fake: 0.2384493504502591 
epoch: 7 | iter: [547/77]G_GAN: 0.4358441038116528 G_L1: 2.4776052942701208 D_real: 0.26205758180967564 D_fake: 0.24355208697568648 
epoch: 8 | iter: [625/77]G_GAN: 0.39639808569744134 G_L1: 2.3021374098054923 D_real: 0.214940996306717 D_fake: 0.24405436566585947 
epoch: 9 | iter: [703/77]G_GAN: 0.4841326187560513 G_L1: 2.275581183706879 D_real: 0.21305256740302797 D_fake: 0.2327301459932688 
epoch: 10 | iter: [781/77]G_GAN: 0.5268422517047566 G_L1: 2.6015355298473577 D_real: 0.19361401168973583 D_fake: 0.21397148724941975 
epoch: 11 | iter: [859/77]G_GAN: 0.4600877416361669 G_L1: 2.3329689927921176 D_real: 0.19201207991428437 D_fake: 0.22674677735135243 
epoch: 12 | iter: [937/77]G_GAN: 0.37059199288012873 G_L1: 2.2006277187614685 D_real: 0.2365176947253525 D_fake: 0.2520092704398617 
epoch: 13 | iter: [1015/77]G_GAN: 0.3408908325775414 G_L1: 2.0173100453273505 D_real: 0.23234153325390663 D_fake: 0.24667616900365064 
epoch: 14 | iter: [1093/77]G_GAN: 0.34680410650125737 G_L1: 2.04246805579799 D_real: 0.2214475262696576 D_fake: 0.23889502852111105 
epoch: 89 | iter: [6943/77]G_GAN: 0.2642161326043925 G_L1: 1.0221970142072934 D_real: 0.24478925280510241 D_fake: 0.24600810590822986 
epoch: 90 | iter: [7021/77]G_GAN: 0.26738060128157304 G_L1: 1.012347730861348 D_real: 0.24634280554048574 D_fake: 0.2443215009892822 
epoch: 91 | iter: [7099/77]G_GAN: 0.2670001643858138 G_L1: 1.020124284325132 D_real: 0.2478118227545623 D_fake: 0.24104121289435465 
epoch: 92 | iter: [7177/77]G_GAN: 0.2613557884647588 G_L1: 1.0107599322203618 D_real: 0.24603542154002342 D_fake: 0.24897599523993813 
epoch: 93 | iter: [7255/77]G_GAN: 0.26482251571242216 G_L1: 1.003135530052671 D_real: 0.2475697593704151 D_fake: 0.24258741489641225 
epoch: 94 | iter: [7333/77]G_GAN: 0.2615386551352823 G_L1: 0.9973514452102078 D_real: 0.24512156502456423 D_fake: 0.24434730600399576 
epoch: 95 | iter: [7411/77]G_GAN: 0.26198578792013183 G_L1: 0.982191018997484 D_real: 0.24517902219371432 D_fake: 0.2430070811396192 
epoch: 96 | iter: [7489/77]G_GAN: 0.26012317845775823 G_L1: 0.9870044896557073 D_real: 0.24992746589290107 D_fake: 0.24502807532905774 
epoch: 97 | iter: [7567/77]G_GAN: 0.2599389344263988 G_L1: 0.9592056259228166 D_real: 0.24294976766701717 D_fake: 0.24391981864431103 
epoch: 98 | iter: [7645/77]G_GAN: 0.259126479458657 G_L1: 0.9704558659511008 D_real: 0.24706423168729066 D_fake: 0.24465526156364734 
epoch: 99 | iter: [7723/77]G_GAN: 0.256876720364686 G_L1: 0.9600363734421457 D_real: 0.24648307216395238 D_fake: 0.24631513322994208 
epoch: 100 | iter: [7801/77]G_GAN: 0.26698521899569566 G_L1: 0.9539595963848624 D_real: 0.2524758789949356 D_fake: 0.23585787795151875 
"""

# Extract data using regex
epochs = []
G_GAN = []
G_L1 = []
D_real = []
D_fake = []

# Regex pattern to extract the values
pattern = re.compile(r"epoch: (\d+) .*?G_GAN: ([\d\.]+) G_L1: ([\d\.]+) D_real: ([\d\.]+) D_fake: ([\d\.]+)")

# Parse the data
for match in pattern.finditer(data):
    epochs.append(int(match.group(1)))
    G_GAN.append(float(match.group(2)))
    G_L1.append(float(match.group(3)))
    D_real.append(float(match.group(4)))
    D_fake.append(float(match.group(5)))

# Plot the data
plt.figure(figsize=(10, 6))

plt.plot(epochs, G_GAN, label='G_GAN', color='blue')
plt.plot(epochs, G_L1, label='G_L1', color='orange')
plt.plot(epochs, D_real, label='D_real', color='green')
plt.plot(epochs, D_fake, label='D_fake', color='red')

plt.xlabel('Epoch')
plt.ylabel('Values')
plt.legend()
plt.title('Training Loss and Metrics Over Epochs')
plt.show()

plt.savefig('training_metrics.png')
